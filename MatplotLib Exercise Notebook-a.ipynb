# %% [markdown]
# # Matplotlib Exercise AI 240 - 10459
#
# # Instructor - Dr. Uma Gajendragadkar

# %% [markdown]
# ## Use slides from the class and do below exercises
# Use cars dataset if you want for below charts otherwise use data given in slides and draw all below charts in Matplotlib.
#
# Exercise 1 -  Install Matplotlib Library using instruction
#
# !pip install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/matt/miniforge3/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/matt/miniforge3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/matt/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Exercise 2 - Import Matplotlib using
#
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## Exercise 3 - Draw Barchart

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([5, 7, 3, 11])
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Exercise 4 -  Draw Histogram

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()y = np.array([35, 25, 25, 15])

# %% [markdown]
# ## Exercise 5 -  Draw Piechart

# %%
y = np.array([35, 25, 25, 15])

# %%
plt.pie(y)
plt.show()
